# %%
marks=int(input("enter student marks : "))

if(marks >=90):
    grade="A"
elif(marks>=80 and marks<90):
     grade="B"
elif(marks>=70 and marks<80):
     grade="C"
else:
   grade="D"

print("grade of the student ->", grade)

# %%
import random

comp_number = random.randint(1, 21)
guess_num=int(input("Enter a number between 1 to 20 : "))
c=1
while guess_num!=comp_number:
  if guess_num < comp_number:
    print("Bhai thoda bda soch: ")
    guess_num=int(input("Enter a number again: "))
    c+=1

  elif guess_num > comp_number:
    print("Bhai thoda chota soch: ")
    guess_num=int(input("Enter a number again: "))
    c+=1

  else:
    print("Coreect guess: ")
    print("Tune itane attempt liye: ", c)

print("Coreect guess")
print("Tune itane attempt liye: ", c)
# Out:
# Enter a number between 1 to 20 : 2
# Bhai thoda bda soch:
# Enter a number again: 4
# Bhai thoda bda soch:
# Enter a number again: 6
# Bhai thoda bda soch:
# Enter a number again: 8
# Bhai thoda bda soch:
# Enter a number again: 13
# Bhai thoda chota soch:
# Enter a number again: 11
# Coreect guess
# Tune itane attempt liye:  6

# %%
# signal
signal = input("Enter the signal color (red/yellow/green): ")
if signal=="red":
  print("car must Stop")
elif signal=="green":
  print("car must Go")
elif signal=="yellow":
  print("car must Start")
else:
   print("signal off")
# Out:
# Enter the signal color (red/yellow/green): yellow
# car must Start

# %%
a=1
while a<11:
  print("2","X",a,"=",2*a)
  a=a+1
# Out:
# 2 X 1 = 2
# 2 X 2 = 4
# 2 X 3 = 6
# 2 X 4 = 8
# 2 X 5 = 10
# 2 X 6 = 12
# 2 X 7 = 14
# 2 X 8 = 16
# 2 X 9 = 18
# 2 X 10 = 20

# %%
for i in range(4):
  for j in range(4):
    print("*",end=" ")

  print( )
# Out:
# * * * *
# * * * *
# * * * *
# * * * *

# %%
rows=5
for i in range(1,rows+1):
  print("*" * i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
for i in range(1,5):
  print(" "*(4-i),"* "*i)
# Out:
#     *
#    * *
#   * * *
#  * * * *

# %%
# counting of vowells in string
s=input("Enter A String: ")
v="AEIOU"
c=0
for i in s:
  if i.upper() in v:
    c=c+1
print("no. of vowells in string is ", c)
# Out:
# Enter A String: data science
# no. of vowells in string is  5

# %%
import re

# %%
#  type of optimize code
# Creating a strong Password
password=input("Enter your password: ")
if len(password)<8:
  print("Weak password: ")
elif not re.search("[A-Z]",password):
  print("Weak password due to not any uppercase")
elif not re.search("[a-z]",password):
  print("Weak password due to not any lowercase ")
elif not re.search("[0-9]",password):
  print("Weak password due to not any digit/number")
elif not re.search("[!@#$%^&]",password):
  print("Weak password due to not any uppercase")
else:
  print("Strong Password ")
# Out:
# Enter your password: aSdhrf@435
# Strong Password

# %%
print("---- Welcome Dheeraj to your first calculator ----")
user_intput1 = int(input("Bhai ek number bta: "))
user_intput2 = int(input("Bhai dusra number bta: "))
oper_input = input("Bhai kya opertaion karna chahte ho(+,-,*,/) : ")
if oper_input=="+":
  print(user_intput1 + user_intput2)
elif oper_input=="-":
  print(user_intput1 - user_intput2)
elif oper_input=="*":
  print(user_intput1 * user_intput2)
else:
  print(user_intput1 / user_intput2)
# Out:
# ---- Welcome Dheeraj to your first calculator ----
# Bhai ek number bta: 33
# Bhai dusra number bta: 44
# Bhai kya opertaion karna chahte ho(+,-,*,/) : +
# 77

# %%
# Login
email_login=input("Enter your email : ")
passward_login=input("Enter your passward : ")
if email==email_login and passward==passward_login:
  print("Login Sucessfull")
elif email==email_login and passward !=passward_login:
  print("Incorrect Passward")
else:
  print("Incorrect Cradentails")
